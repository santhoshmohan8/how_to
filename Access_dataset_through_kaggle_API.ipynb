# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshmohan8/how_to/blob/main/Access_dataset_through_kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**`Import dataset from Kaggle reporsitory directly`**

# %% [markdown]
# With this method, you dont need to manually search and download datasets for practice problems, you can directly access through kaggle API

# %%
# !pip install -q kaggle

# %% [markdown]
# ### You need to have a copy of kaggle.json file downloaded in your system.
#
# How to download ?
# 1. kaggle.com -> Your profile -> Account
# then click on "Create new token" under API section.
# you will have "kaggle.json" file downloaded
# ![Screenshot 2023-11-02 at 11.19.47 AM.png](data:image/png;base64,...)
#
# 2. "files.upload()" code will prompt for file input, choose "kaggle.json" file

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a2fe759d-ead4-4522-8e9b-d437afbfde75" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a2fe759d-ead4-4522-8e9b-d437afbfde75">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Create directory, change permissions

# %%
! mkdir ~/.kaggle # create directory names kaggle
! cp kaggle.json ~/.kaggle/ # copy json file to the folder kaggle
! chmod 600 ~/.kaggle/kaggle.json # change permissions
! kaggle datasets list # data set list from kaggle

# %% [markdown]
# Now, lets say we need catfish dataset, follow steps as below
# 1. open kaggle link where you have the dataset. https://www.kaggle.com/datasets/agbadutaofejiro/catfish
# 2. copy API command
#
# ![Screenshot 2023-11-02 at 11.28.48 AM.png](data:image/png;base64,...)
#
# 3. Unzip to unzip the dataset file as CSV or other accessible format

# %%
# Line 1 is what you copy
! kaggle datasets download -d vikasukani/parkinsons-disease-data-set
! unzip parkinsons-disease-data-set.zip
